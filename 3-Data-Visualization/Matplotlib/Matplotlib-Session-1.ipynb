# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
import pandas as pd

# %%
hr = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/HR_comma_sep.csv.txt')

# %%
hr
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
hr.rename(columns={'sales':'dept'}, inplace=True)

# %%
res = hr.dept.value_counts()

# %%
res.plot.bar()

# %%
hr.salary.value_counts().plot.bar()

# %%
cols = ['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship'
        ,'race','sex','capital-gain','capital-loss','hours-per-week','native-country','Salary']

# %%
cols=['age','workclass','flano','education','dcdcdc','nevermarried','admclerical','notinfamily','white','gender','gffd','fnvjfnv','jfjfff','us','jnjnf']
adult = pd.read_csv('../../2-Data-Manipulation/Pandas/adult.data.txt', names=cols)
adult.head()
# Out:
#    age          workclass   flano   education  dcdcdc         nevermarried  \
# 0   39          State-gov   77516   Bachelors      13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors      13   Married-civ-spouse
# 2   38            Private  215646     HS-grad       9             Divorced
# 3   53            Private  234721        11th       7   Married-civ-spouse
# 4   28            Private  338409   Bachelors      13   Married-civ-spouse
#
#           admclerical     notinfamily   white   gender  gffd  fnvjfnv  jfjfff  \
# 0        Adm-clerical   Not-in-family   White     Male  2174        0      40
# 1     Exec-managerial         Husband   White     Male     0        0      13
# 2   Handlers-cleaners   Not-in-family   White     Male     0        0      40
# 3   Handlers-cleaners         Husband   Black     Male     0        0      40
# 4      Prof-specialty            Wife   Black   Female     0        0      40
#
#                us   jnjnf
# ...

# %%
adult.columns
# Out:
# Index(['age', 'workclass', 'flano', 'education', 'dcdcdc', 'nevermarried',
#        'admclerical', 'notinfamily', 'white', 'gender', 'gffd', 'fnvjfnv',
#        'jfjfff', 'us', 'jnjnf'],
#       dtype='object')

# %%
adult.education.value_counts().plot.bar()

# %% [markdown]
# ### Scatterplot
# * it's relationship between two columns

# %%
plt.scatter(x=hr.satisfaction_level,y=hr.average_montly_hours, s=10)

# %%
plt.scatter(x=hr.satisfaction_level,y=hr.average_montly_hours, s=10, c=hr.left)
plt.xlabel('satisfaction_level')
plt.ylabel('average_montly_hours')
plt.title('HR')
plt.colorbar()

# %%
hr.plot.scatter(x='satisfaction_level',y='average_montly_hours',s=10,c='left',cmap='cividis')

# %% [markdown]
# ### Questions:

# %%
plt.scatter(x=adult.dcdcdc,y=adult.jfjfff, s=10)

# %%
adult['sex_number'] = adult.gender.map(lambda x: 1 if x== 'Male' else 0)

# %%
plt.scatter(x=adult['dcdcdc'],y=adult['jfjfff'], s=5, c=adult['sex_number'],cmap='viridis')

# %% [markdown]
# ### Pie charts
# * small distribution information

# %%
education
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %%
education = adult.education.value_counts()
plt.pie(x=education, labels=education.index, autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x25274f21648>,
# ...
#  [Text(0.5820899380125792, 0.9333655790013428, ' HS-grad'),
#   Text(-1.0080460983118946, 0.44027612208495526, ' Some-college'),
#   Text(-0.7597721283465596, -0.7954535266046276, ' Bachelors'),
#   Text(-0.08741327393996691, -1.096521280933068, ' Masters'),
#   Text(0.24008494758967386, -1.0734799569348576, ' Assoc-voc'),
#   Text(0.4949730840386798, -0.9823449730503222, ' 11th'),
#   Text(0.694280840521506, -0.8532139910273104, ' Assoc-acdm'),
#   Text(0.8450166685674572, -0.704234925179912, ' 10th'),
#   Text(0.942102978552347, -0.5678397465859502, ' 7th-8th'),
#   Text(1.0023572365721214, -0.45307832688344374, ' Prof-school'),
#   Text(1.0443802910268456, -0.3453546115439627, ' 9th'),
#   Text(1.0715349148116406, -0.2486220552155627, ' 12th'),
#   Text(1.0882384969803631, -0.16042747174321548, ' Doctorate'),
#   Text(1.0969578840449365, -0.0817520680573624, ' 5th-6th'),
# ...
