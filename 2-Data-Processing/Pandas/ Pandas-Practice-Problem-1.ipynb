# %%
import pandas as pd

# %%
winamag = pd.read_csv('https://raw.githubusercontent.com/edyoda/Data-Scientist-program/master/Practice%20Problems/data/winemag.csv', encoding = "ISO-8859-1")

# %%
winamag
# Out:
#         Unnamed: 0   country  \
# 0              0.0     Italy
# 1              1.0  Portugal
# 2              2.0        US
# 3              3.0        US
# 4              4.0        US
# ...            ...       ...
# 129863         NaN       NaN
# 129864         NaN       NaN
# 129865         NaN       NaN
# 129866         NaN       NaN
# 129867         NaN       NaN
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129863                                                NaN
# 129864                                                NaN
# 129865                                                NaN
# ...

# %% [markdown]
# ### 1. Create a dataframe fruit_sales that matches the diagram below

# %%
winamag.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'Unnamed: 5', 'province', 'region_1', 'region_2', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')

# %%
fruit_sales = winamag[['country','description','province']]

# %%
fruit_sales.set_index('province', inplace=True)

# %%
fruit_sales.loc['Oregon']
# Out:
#          country                                        description
# province
# Oregon        US  Tart and snappy, the flavors of lime flesh and...
# Oregon        US  Much like the regular bottling from 2012, this...
# Oregon        US  A sleek mix of tart berry, stem and herb, alon...
# Oregon        US  As with many of the Erath 2010 vineyard design...
# Oregon        US  A stiff, tannic wine, this slowly opens and br...
# ...          ...                                                ...
# Oregon        US  Despite the famed vineyard on the label, this ...
# Oregon        US  Planted in 1988, this vineyard 's fruit captur...
# Oregon        US  Despite the low alcohol reading, this comes ac...
# Oregon        US  At David Hill, the Winemakers Cuvï¿½ï¿½e is a ...
# Oregon        US  A subtle wine, with delicate, lightly buttery ...
#
# [3332 rows x 2 columns]

# %%
fruit_sales.reset_index(inplace=True)

# %%
fruit_sales
# Out:
#                  province   country  \
# 0       Sicily & Sardinia     Italy
# 1                   Douro  Portugal
# 2                  Oregon        US
# 3                Michigan        US
# 4                  Oregon        US
# ...                   ...       ...
# 129863                NaN       NaN
# 129864                NaN       NaN
# 129865                NaN       NaN
# 129866                NaN       NaN
# 129867                NaN       NaN
#
#                                               description
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129863                                                NaN
# ...
